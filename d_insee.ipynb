# %% [markdown]
# voir les liens suivants :
# https://www.insee.fr/fr/metadonnees/source/serie/s1172
# https://portail-api.insee.fr/catalog/api/a890b735-159c-4c91-90b7-35159c7c9126/doc?page=ee625968-272a-4637-a259-68272aa63766
# https://catalogue-donnees.insee.fr/fr/catalogue/recherche/DS_RP_EMPLOI_LR_PRINC

# %%
import requests

# %%
url_base = "https://api.insee.fr/melodi/data/DS_RP_EMPLOI_LR_PRINC"
response = requests.get(url_base)

# %%
type(response)
# Out:
# requests.models.Response

# %%
data = response.json()

# %%
data["paging"]
# Out:
# {'first': 'https://api.insee.fr/melodi/data/DS_RP_EMPLOI_LR_PRINC?page=1',
#  'next': 'https://api.insee.fr/melodi/data/DS_RP_EMPLOI_LR_PRINC?page=2',
#  'isLast': False}

# %%
url_base = "https://api.insee.fr/melodi/data/DS_RP_EMPLOI_LR_PRINC?page=1"
response = requests.get(url_base)

# %%
data = response.json()

# %%
# Out:
# {'identifier': 'DS_RP_EMPLOI_LR_PRINC', 'title': {'fr': 'Population active et chômage', 'en': 'Labor force and unemployment'}, 'publisher': {'id': 'INSEE', 'label': [{'lang': 'fr', 'content': 'Institut national de la statistique et des etudes economiques (INSEE)'}, {'lang': 'en', 'content': 'National Institute of Statistics and Economic Studies'}]}, 'observations': [{'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/e512912f-3279-478b-8ec4-b3579bcd3344', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '1', 'TIME_PERIOD': '2021', 'RP_MEASURE': 'POP', 'EDUC': '350T351_RP', 'AGE': 'Y15T64'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 33.79918}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/a9a67e47-375b-48df-b7a9-3b0350f6451c', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '1', 'TIME_PERIOD': '2010', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y55T64'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 13.06075}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/7a628dc0-a765-4754-b453-53c4cf39c042', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '35', 'TIME_PERIOD': '2021', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y55T64'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 3.02721}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/9717c619-b5d1-44f9-8143-9f95c59c07d2', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '2', 'TIME_PERIOD': '2015', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y_GE15'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 42.08789}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/b4bd5072-1db6-4136-9a59-b44c4c6ec4cc', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '36', 'TIME_PERIOD': '2010', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y25T54'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 1.02797}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/80615f27-babd-445f-a98d-e32013e2806d', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '_T', 'TIME_PERIOD': '2021', 'RP_MEASURE': 'POP', 'EDUC': '600_RP', 'AGE': 'Y15T64'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 35.1615}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/e0f9b896-bc0a-45de-8574-98b7b4a6d3c9', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '35', 'TIME_PERIOD': '2021', 'RP_MEASURE': 'POP', 'EDUC': '700_RP', 'AGE': 'Y15T64'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 0.9625}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/fc06e3e2-6983-43e2-812c-4ed7efefa9b0', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '33', 'TIME_PERIOD': '2015', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y_GE15'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 18.57179}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/fef32138-2559-45ab-96ee-f26c73b08a65', 'SEX': 'F', 'FREQ': 'A', 'EMPSTA_ENQ': '2', 'TIME_PERIOD': '2021', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y25T54'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 23.09854}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/7f9ef878-106a-4d5d-95eb-ad92d86ecd42', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '_T', 'TIME_PERIOD': '2015', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y15T24'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 23.57758}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/bassinDeVie2022/d0e31009-d5f3-450d-ae90-0821f408df3a', 'SEX': 'F', 'FREQ': 'A', 'EMPSTA_ENQ': '2', 'TIME_PERIOD': '2021', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y55T64'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 153.57689}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/departement/1881a325-4331-41ba-b807-6ac5deb9dced', 'SEX': 'F', 'FREQ': 'A', 'EMPSTA_ENQ': '31', 'TIME_PERIOD': '2021', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y55T64'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 5482.11958}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/cb552cee-bee3-4d28-b270-90d349bbaacc', 'SEX': '_T', 'FREQ': 'A', 'EMPSTA_ENQ': '35', 'TIME_PERIOD': '2010', 'RP_MEASURE': 'POP', 'EDUC': '_T', 'AGE': 'Y_GE15'}, 'measures': {'OBS_VALUE_NIVEAU': {'value': 619.14446}}}, {'dimensions': {'GEO': 'http://id.insee.fr/geo/commune/a7b4de54-16b5-44ea-88 ...
